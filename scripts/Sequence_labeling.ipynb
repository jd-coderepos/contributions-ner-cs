# %%
pwd
# Out:
# '/content'

# %%
# !wget https://nlp.stanford.edu/data/glove.6B.zip -P ./drive/MyDrive/GloVe
# Out:
# --2021-10-18 14:07:16--  https://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2021-10-18 14:07:16--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘./drive/MyDrive/GloVe/glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  4.83MB/s    in 2m 53s
#
# 2021-10-18 14:10:10 (4.75 MB/s) - ‘./drive/MyDrive/GloVe/glove.6B.zip’ saved [862182613/862182613]

# %%
# !unzip ./drive/MyDrive/GloVe/glove.6B.zip -d ./drive/MyDrive/GloVe/
# Out:
# Archive:  ./drive/MyDrive/GloVe/glove.6B.zip
#   inflating: ./drive/MyDrive/GloVe/glove.6B.50d.txt
#   inflating: ./drive/MyDrive/GloVe/glove.6B.100d.txt
#   inflating: ./drive/MyDrive/GloVe/glove.6B.200d.txt
#   inflating: ./drive/MyDrive/GloVe/glove.6B.300d.txt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/jiesutd/NCRFpp.git
# Out:
# Cloning into 'NCRFpp'...
# remote: Enumerating objects: 768, done.
# remote: Total 768 (delta 0), reused 0 (delta 0), pack-reused 768
# Receiving objects: 100% (768/768), 6.89 MiB | 10.80 MiB/s, done.
# Resolving deltas: 100% (484/484), done.

# %%
cd NCRFpp/
# Out:
# /content/NCRFpp

# %%
# !python main.py --config ../drive/MyDrive/research-problem-labeling/train.config
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#      Instance: 2000; Time: 2.24s; loss: 111.0249; acc: 13239/17356=0.7628
#      Instance: 2500; Time: 2.37s; loss: 103.1465; acc: 16617/21783=0.7628
#      Instance: 3000; Time: 2.02s; loss: 101.7399; acc: 19831/26037=0.7616
#      Instance: 3500; Time: 2.23s; loss: 96.4920; acc: 23286/30442=0.7649
#      Instance: 4000; Time: 2.06s; loss: 96.5267; acc: 26680/34747=0.7678
#      Instance: 4500; Time: 2.28s; loss: 100.7965; acc: 29970/39088=0.7667
#      Instance: 5000; Time: 2.02s; loss: 99.7986; acc: 33324/43389=0.7680
#      Instance: 5500; Time: 2.26s; loss: 94.9382; acc: 36660/47645=0.7694
#      Instance: 6000; Time: 2.11s; loss: 112.9102; acc: 39777/51883=0.7667
#      Instance: 6500; Time: 2.32s; loss: 100.9556; acc: 43126/56179=0.7677
#      Instance: 7000; Time: 2.34s; loss: 98.1602; acc: 46485/60613=0.7669
#      Instance: 7500; Time: 2.44s; loss: 102.4674; acc: 49866/64988=0.7673
# ...

# %%
# !python main.py --config ../drive/MyDrive/research-problem-labeling/decode.config
# Out:
# Seed num: 42
# MODEL: decode
# ../drive/MyDrive/research-problem-labeling/test.data
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BMES
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 250
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 29727
#      Char  alphabet size: 86
#      Label alphabet size: 30
#      Word embedding  dir: None
#      Char embedding  dir: None
#      Word embedding size: 50
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: ../drive/MyDrive/research-problem-labeling/train.data
#      Dev    file directory: ../drive/MyDrive/research-problem-labeling/dev.data
#      Test   file directory: ../drive/MyDrive/research-problem-labeling/test.data
# ...
